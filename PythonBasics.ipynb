# %% [markdown]
# # Introduction to Python & Algorithmic Basics
# This notebook covers basic syntax, essential structures, and core algorithmic optimization paradigms in Python.
#
# **Useful resources**:
# - [Python Tutorial](https://www.geeksforgeeks.org/python/python-programming-language-tutorial/)

# %% [markdown]
# ## 1. Core Python Basics
# This section provides a checklist of fundamental native types and expressions.

# %% [markdown]
# ### Variables and operation
# Change `x` and `y` values and observe the changes.

# %%
x = 10
y = 3.5
# Arithmetic
print("Arithmetic operations:")
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x**2)
# Boolean
print("\nBoolean operations:")
print(x == y)
print(x <= y)
print(x > y)
# Out:
# Arithmetic operations:
# 13.5
# 6.5
# 35.0
# 2.857142857142857
# 100
#
# Boolean operations:
# False
# False
# True

# %% [markdown]
# ## 2. Data Structures: [List](https://www.geeksforgeeks.org/python/python-lists/), [Strings](https://www.geeksforgeeks.org/python/python-string/), [Dictionary](https://www.geeksforgeeks.org/python/python-dictionary/), [Set](https://www.geeksforgeeks.org/python/sets-in-python/)
# Feel free to check out the links to discover other examples and methods not included in the examples below.

# %%
# Lists
demo_list = [1, 4, 2, 5, 3]
# List size
print("List size: ", len(demo_list))
# Add an element at the end
demo_list.append(6)
print("Append 6:", demo_list)
# Remove an element
demo_list.remove(6)
print("Remove 6:", demo_list)
# Concatenate lists
demo_list += [7, 6]
print("Concatenate with [7,6]:", demo_list)
# Sort list
demo_list = sorted(demo_list)
print("Sorted list:", demo_list)
# Slicing
# Indices go from 0 to len(demo_list) - 1
# You can create subsets of a list
# From the beginning to index 3.
print("Beginning to index 3 subset:", demo_list[:4]) # Extracts index 0, 1, 2, 3. Index 4 is excluded
# From index 3 to the end.
print("From index 3 to end subset:", demo_list[3:])
# Between index 1 and 3
print("From index 1 to index 3 subset:", demo_list[1:4])
# Out:
# List size:  5
# Append 6: [1, 4, 2, 5, 3, 6]
# Remove 6: [1, 4, 2, 5, 3]
# Concatenate with [7,6]: [1, 4, 2, 5, 3, 7, 6]
# Sorted list: [1, 2, 3, 4, 5, 6, 7]
# Beginning to index 3 subset: [1, 2, 3, 4]
# From index 3 to end subset: [4, 5, 6, 7]
# From index 1 to index 3 subset: [2, 3, 4]

# %%
# Strings
a = "Hello world !"
b = "I'll be back !"
print(a[0]) # Extract a character
print(a[:5]) # Extract a word
print(a + " " + b) # Concatenate strings
# Example: Remove spaces
words = a.split(" ")
print(words)
print("".join(words))
# Out:
# H
# Hello
# Hello world ! I'll be back !
# ['Hello', 'world', '!']
# Helloworld!

# %% [markdown]
# 1. Run the following code once
# 2. Replace `apple_key = "apple"` by `apple_key = "appl"`. What happens ?
# 3. Comment (Add #) line 7 and uncomment line 8. What's apple value ?

# %%
# Dictionary
demo_dict = {"apple": 5, "banana": 3}  # Key-Value pairs
print("Keys:", list(demo_dict.keys()))
print("Values:", list(demo_dict.values()))
print([f"Key: {key} / Value {value} " for key, value in demo_dict.items()])
# Get value
apple_key = "apple"
apple_value = demo_dict[apple_key]
# apple_value = demo_dict.get(apple_key, None)
print("Apple value:", apple_value)
# Change value
demo_dict[apple_key] = 10
print("New apple value:", demo_dict[apple_key])
# Out:
# Keys: ['apple', 'banana']
# Values: [5, 3]
# ['Key: apple / Value 5 ', 'Key: banana / Value 3 ']
# Apple value: 5
# New apple value: 10

# %%
# Set
demo_set = {1, 3, 2, 2}  # Unordered, unique elements only ({1, 2, 3})
# Add new value
demo_set.add(4)
print("Added 4:", demo_set)
# Add existing value
demo_set.add(2)
print("Added 2 (no changes):", demo_set)
# Out:
# Added 4: {1, 2, 3, 4}
# Added 2 (no changes): {1, 2, 3, 4}

# %% [markdown]
# ## 3. [Conditional Statements](https://www.geeksforgeeks.org/python/conditional-statements-in-python/)
# Change `x` value to display the three states.

# %%
x = 10
if x < 5:
    print("Small")
elif x == 10:
    print("Target")
else:
    print("Large")
# Out:
# Target

# %% [markdown]
# ## 5. [Loops](https://www.geeksforgeeks.org/python/loops-in-python/)

# %% [markdown]
# ### 5.1 For loop
# Best when the number of iterations is known beforehand. The size of the object size you're iterating over shouldn't change during the loop.

# %%
vector1 = [1, 2, 3, 4, 5]
vector2 = [6, 7, 8, 9, 10]
# Iterate over the list values
print("By value:")
for value in vector1:
    print(value)
print("\n")
# Iterate over the list using index
for i in range(len(vector1)):
    print(f"Index: {i} / Value: {vector1[i]}")
print("\n")
# Iterate over two vectors
for value1, value2 in zip(vector1, vector2):
    print(f"Value1: {value1} / Value2: {value2}")
# Out:
# By value:
# 1
# 2
# 3
# 4
# 5
#
#
# Index: 0 / Value: 1
# Index: 1 / Value: 2
# Index: 2 / Value: 3
# Index: 3 / Value: 4
# Index: 4 / Value: 5
#
#
# Value1: 1 / Value2: 6
# Value1: 2 / Value2: 7
# Value1: 3 / Value2: 8
# Value1: 4 / Value2: 9
# Value1: 5 / Value2: 10

# %% [markdown]
# ### 5.2 While loop
# Best when looping depends on a dynamic condition. Risks infinite loops if the exit condition is never satisfied.

# %%
vector1 = [1, 2, 3, 4, 5]
index = 0
while len(vector1) > 0: # Stops when there are no more items left in the list
    value = vector1.pop(0) # Remove first element at each iteration
    index += 1
    print(f"Index: {index} / Value: {value} / Vector size: {len(vector1)}")
# Out:
# Index: 1 / Value: 1 / Vector size: 4
# Index: 2 / Value: 2 / Vector size: 3
# Index: 3 / Value: 3 / Vector size: 2
# Index: 4 / Value: 4 / Vector size: 1
# Index: 5 / Value: 5 / Vector size: 0

# %% [markdown]
# ## 4. [Functions](https://www.geeksforgeeks.org/python/python-functions/)

# %%
# Basic example
def greet_user(name: str ="Guest"):
    """Simple function template returning a string."""
    return f"Hello, {name}!"
print("Default function value:", greet_user())
print("Custom function value:", greet_user("Admin"))
# Out:
# Default function value: Hello, Guest!
# Custom function value: Hello, Admin!

# %% [markdown]
# ### 4.1 Exercise 1
# The goal of this exercise is to determine the average class level.
#
# Inputs:
#
# - List `class_marks` containing students marks from 0 to 20.
# - Dictionary `class_levels`.
#
# Output:
#
# - Class average mark
# - Class level string
# 1. Implement `average_mark` method.
# 2. Implement `average_class_level` method. (Hint: Handle extreme cases and then iterate over the intervals)
# 3. Implement `get_class_level` that calls `average_mark` and `average_class_level` methods.

# %%
import random
# Generating random marks between 0 and 20
students_count = 30
class_marks = [random.random() * 20 for i in range(students_count)]
class_levels = {16: "Very good", 14: "Good", 12: "Good enough", 10: "Neutral"}

# %%
def average_mark(marks: list) -> float:
    return sum(marks) / len(marks)
# Test
vector = [1, 2, 3, 4, 5]
assert average_mark(vector) == 3

# %%
def average_class_level(average_mark_value: float, levels: dict[float, str]) -> str:
    keys = list(levels.keys())
    sorted_keys = sorted(keys)
    if average_mark_value <= sorted_keys[0]:
        return levels[sorted_keys[0]]
    elif average_mark_value >= sorted_keys[-1]:
        return levels[sorted_keys[-1]]
    else:
        for key_index in range(len(sorted_keys) - 1):
            if sorted_keys[key_index] <= average_mark_value < sorted_keys[key_index + 1]:
                return levels[sorted_keys[key_index]]
        return "Unknown"

# Tests
assert average_class_level(18, class_levels) == "Very good"
assert average_class_level(16, class_levels) == "Very good"
assert average_class_level(15, class_levels) == "Good"
assert average_class_level(14, class_levels) == "Good"
assert average_class_level(13, class_levels) == "Good enough"
assert average_class_level(12, class_levels) == "Good enough"
assert average_class_level(11, class_levels) == "Neutral"
assert average_class_level(10, class_levels) == "Neutral"
assert average_class_level(3, class_levels) == "Neutral"

# %%
def get_class_level(marks: list[float], levels: dict[float, str]) -> tuple[float, str]:
    average_mark_value = average_mark(marks)
    level_value = average_class_level(average_mark_value, levels)
    return average_mark_value, level_value
mark, level = get_class_level(class_marks, class_levels)
print("Class average mark is ", mark, "which corresponds to a", level, "level.")
# Out:
# Class average mark is  8.880845993112953 which corresponds to a Neutral level.

# %% [markdown]
# ### 5.2 [Palindrome](https://en.wikipedia.org/wiki/Palindrome)
# The goal is to count the number of palindromes in a list.
# 1. Implement `is_palindrome` method.
# 2. Implement `palindrome_count` method.

# %%
def is_palindrome(a_word: str) -> bool:
    left_index, right_index = 0, len(a_word) - 1
    while left_index < right_index:
        if a_word[left_index] != a_word[right_index]:
            return False
        left_index += 1
        right_index -= 1
    return True

# %%
def palindrome_count(some_words: list[str]) -> int:
    value_count = 0
    for a_word in some_words:
        if is_palindrome(a_word):
            value_count += 1
    return value_count
words = ["civic", "monkey", "plate", "kayak", "radar", "fish", "level", "racoon"]
count = palindrome_count(words)
print("Found ", count, " palindromes in the list.")
assert count == 4
# Out:
# Found  4  palindromes in the list.

# %% [markdown]
# ### 5.3 Object search
# 1. Implement `linear_search` which takes as an input a list of values and the object we're looking and returns `True` if the object is in the list, `False` otherwise.
# 2. Run the binary search cell.
# 3. Which algorithm is faster ? Why ? (Help: [Binary search](https://www.geeksforgeeks.org/dsa/binary-search/))

# %%
target = 1000000
vector = [i for i in range(target)]

# %%
def linear_search(some_values: list[int], a_target: int) -> bool:
    for value in some_values:
        if value == a_target:
            return True
    return False
import time
start = time.time()
linear_search(vector, target)
print("Target found in", time.time() - start, "seconds.")
# Out:
# Target found in 0.01261448860168457 seconds.

# %%
def binary_search(arr: list[int], a_target: int) -> bool:
    low, high = 0, len(arr) - 1
    while low <= high:
        m = low + (high - low) // 2
        # Check if x is present at mid
        if arr[m] == a_target:
            return True

        # If x is greater, ignore left half
        elif arr[m] < a_target:
            low = m + 1

        # If x is smaller, ignore right half
        else:
            high = m - 1
    return False
import time
start = time.time()
binary_search(vector, target)
print("Target found in", time.time() - start, "seconds.")
# Out:
# Target found in 4.3392181396484375e-05 seconds.

# %% [markdown]
# ## 6. [Exception handling](https://www.geeksforgeeks.org/python/python-exception-handling/)
# It allows a program to handle unexpected errors during execution in a controlled way, instead of crashing abruptly. It enables programs to detect errors, manage them properly and continue execution wherever possible.

# %%
# Example n°1
n = 10
try:
    res = n / 0
except ZeroDivisionError:
    print("Can't be divided by zero!")
finally:
    print("Program terminated normally!")
# Out:
# Can't be divided by zero!
# Program terminated normally!

# %%
# Example
try:
    # This key doesn't exist in demo_dict. It will raise a KeyError.
    demo_dict["fish"]
except KeyError as e:
    print("Invalid key:", e)
finally:
    print("Program terminated normally!")
# Out:
# Invalid key: 'fish'
# Program terminated normally!
